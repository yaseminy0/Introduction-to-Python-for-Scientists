# %%
from tic_tac_toe import PlayGame

# %%
PlayGame()
# Out:
# Wellcome to Tic Tac Toe Game
# Set the steps for ComputerPlayer so that it could think N steps ahead: N= 1
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Human player goes first
# Please input the row index (0, 1, or 2):  1
# Please input the column index (0, 1, or 2):  1
#  | |
# -+-+-
#  |X|
# -+-+-
#  | |
# The game is still in progress
#  | |
# -+-+-
#  |X|O
# -+-+-
#  | |
# The game is still in progress
# Please input the row index (0, 1, or 2):  0
# Please input the column index (0, 1, or 2):  2
#  | |X
# -+-+-
#  |X|O
# -+-+-
#  | |
# The game is still in progress
#  | |X
# -+-+-
#  |X|O
# -+-+-
# O| |
# The game is still in progress
# Please input the row index (0, 1, or 2):  0
# Please input the column index (0, 1, or 2):  0
# X| |X
# -+-+-
#  |X|O
# -+-+-
# O| |
# The game is still in progress
# X|O|X
# -+-+-
#  |X|O
# -+-+-
# O| |
# The game is still in progress
# Please input the row index (0, 1, or 2):  1
# Please input the column index (0, 1, or 2):  0
# X|O|X
# -+-+-
# X|X|O
# ...
